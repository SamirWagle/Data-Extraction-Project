# %%
# %pip install pymupdf
# %pip install frontend
# %pip install pillow
# Out:
# Requirement already satisfied: pymupdf in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (1.23.7)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: PyMuPDFb==1.23.7 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from pymupdf) (1.23.7)
# Requirement already satisfied: frontend in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (0.0.3)
# Requirement already satisfied: starlette>=0.12.0 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from frontend) (0.33.0)
# Requirement already satisfied: uvicorn>=0.7.1 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from frontend) (0.24.0.post1)
# Requirement already satisfied: itsdangerous>=1.1.0 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from frontend) (2.1.2)
# Requirement already satisfied: aiofiles in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from frontend) (23.2.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from starlette>=0.12.0->frontend) (4.1.0)
# Requirement already satisfied: click>=7.0 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from uvicorn>=0.7.1->frontend) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from uvicorn>=0.7.1->frontend) (0.14.0)
# Requirement already satisfied: idna>=2.8 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.4.0->starlette>=0.12.0->frontend) (3.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.4.0->starlette>=0.12.0->frontend) (1.3.0)
# Requirement already satisfied: colorama in c:\users\samir\appdata\roaming\python\python312\site-packages (from click>=7.0->uvicorn>=0.7.1->frontend) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pillow in c:\users\samir\appdata\local\programs\python\python312\lib\site-packages (10.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from PIL import Image, ImageDraw
from io import BytesIO
import fitz

pdf_dir = "C:/Users/samir/OneDrive/Desktop/Data Extraction/Train Files/1040_file_20.pdf"  # Replace with your PDF file path
doc = fitz.open(pdf_dir)
page = doc[0]

blocks = page.get_text("dict")['blocks']
text_blocks = [block for block in blocks if block['type'] == 0]
color = 'red'
width = 2
TARGET_DPI = 300
mat = fitz.Matrix(TARGET_DPI / 72, TARGET_DPI / 72)
pix_map = doc[0].get_pixmap(matrix=mat)
image = Image.open(BytesIO(pix_map.tobytes()))
draw = ImageDraw.Draw(image)

for block in text_blocks:
    for line in block['lines']:
        for span in line['spans']:
            # x0, y0, x1, y1 = [coord * TARGET_DPI / 72 for coord in span['bbox']]
            x0, y0, x1, y1 = 1175.3499984741211,504.62296803792316,306.6750208536784,542.1229680379232
            if x0 > x1:
             x0, x1 = x1, x0
            if y0 > y1:
                y0, y1 = y1, y0
            draw.rectangle((x0, y0, x1, y1), fill=None, outline='green', width=width)

# Display or save the modified image
image.show()
# image.save("output_image.png")  # Uncomment to save the image
with open("C:/Users/samir/OneDrive/Desktop/Data Extraction/Train Files/output.png", "wb") as output_file:
  image.save(output_file)

# %%
coordinates_list = [
  # left bottom right top
    [125.3499984741211, 493.64999135335285, 970.7000211079915, 545.1749801635742],
    [1000.4500147501627, 493.8230616251628, 1950.2874806722004, 545.3230616251627],
    [2100.854176839193, 1526.5500386555989, 2400.479949951172, 1570.6249593098958],
    [2100.595743815104, 1579.3500264485676, 2400.7879435221353, 1619.4249471028645],
    [2100.0707092285156, 1629.6000162760417, 2400.262908935547, 1669.6749369303386],
    [2189.854176839193, 1675.2000172932942, 2311.479949951172, 1715.274937947591],
    [2189.854176839193, 1526.5500386555989, 2311.479949951172, 1566.6249593098958],
    [2190.979258219401, 1727.8500874837239, 2312.6050313313804, 1767.9250081380208],
    [2184.070841471354, 1775.8500417073567, 2321.913401285807, 1815.9249623616536],
    [2208.3958943684897, 1965.1500701904297, 2297.588094075521, 2005.2249908447266],
    [2190.979258219401, 2029.800033569336, 2312.6050313313804, 2069.874954223633],
    [2192.1791076660156, 2080.2000681559243, 2313.8048807779946, 2120.274988810221],
    [2194.579060872396, 2130.4500579833984, 2316.204833984375, 2170.525105794271],
    [2218.9041137695312, 2176.0498046875, 2291.8795267740884, 2216.1249796549478],
    [2182.8707377115884, 2231.0999552408853, 2320.7132975260415, 2271.1751302083335],
    [2209.595743815104, 2322.149912516276, 2298.7879435221353, 2362.225087483724],
    [2192.1791076660156, 2379.7498067220054, 2313.8048807779946, 2419.824981689453],
    [2189.854176839193, 2427.599843343099, 2311.479949951172, 2467.675018310547],
    [2186.4707946777344, 2477.9998779296875, 2324.3133544921875, 2518.0750528971353],
    [2185.2709452311196, 2525.999959309896, 2323.1135050455728, 2566.0751342773438],
    [2201.487477620443, 2576.2499491373696, 2306.8964640299478, 2616.325124104818],
    [2190.979258219401, 2626.6499837239585, 2312.6050313313804, 2666.7251586914062],
    [2193.3792114257812, 2676.899973551432, 2315.0049845377603, 2716.9751485188804],
    [2193.3792114257812, 2676.899973551432, 2315.0049845377603, 2716.9751485188804]
]

from PIL import Image, ImageDraw
from io import BytesIO
import fitz

pdf_dir = "C:/Users/samir/OneDrive/Desktop/Data Extraction/Train Files/1040_file_20.pdf"  # Replace with your PDF file path
doc = fitz.open(pdf_dir)
page = doc[0]

blocks = page.get_text("dict")['blocks']
text_blocks = [block for block in blocks if block['type'] == 0]
color = 'red'
width = 2
TARGET_DPI = 300
mat = fitz.Matrix(TARGET_DPI / 72, TARGET_DPI / 72)
pix_map = doc[0].get_pixmap(matrix=mat)
image = Image.open(BytesIO(pix_map.tobytes()))
draw = ImageDraw.Draw(image)

# Loop through the list of coordinates
for coordinates in coordinates_list:
    x0, y0, x1, y1 = coordinates
    draw.rectangle((x0, y0, x1, y1), fill=None, outline='green', width=width)


image.show()
# image.save("output_image.png")  # Uncomment to save the image
with open("C:/Users/samir/OneDrive/Desktop/Data Extraction/Train Files/output.png", "wb") as output_file:
  image.save(output_file)

# %%
#from PIL import Image, ImageDraw
#from io import BytesIO
import fitz

pdf_dir = "C:/Users/samir/OneDrive/Desktop/Data Extraction/Train Files/1040_file_33.pdf"  # Replace with your PDF file path
doc = fitz.open(pdf_dir)
page = doc[0]

# Define the text you want to find
target_text = "9038.633"
target_x0, target_y0,target_x1,target_y1=0,0,0,0


blocks = page.get_text("dict")['blocks']
text_blocks = [block for block in blocks if block['type'] == 0]

for block in text_blocks:
    for line in block['lines']:
        for span in line['spans']:
            if target_text in span['text']:
                x0, y0, x1, y1 = [coord * TARGET_DPI / 72 for coord in span['bbox']]
                target_x0, target_y0,target_x1,target_y1=x0,y0,x1,y1

                print(f"Found '{target_text}' at coordinates: target_x0, target_y0,target_x1,target_y1={x0},{y0}, {x1},{y1}")

# Rest of your code for drawing or saving the image
# Display or save the modified image
image.show()
# image.save("output_image.png")  # Uncomment to save the image
with open("C:/Users/samir/OneDrive/Desktop/Data Extraction/Train Files/output_2.png", "wb") as output_file:
  image.save(output_file)
# Out:
# Found '9038.633' at coordinates: target_x0, target_y0,target_x1,target_y1=2190.979258219401,1727.8500874837239, 2312.6050313313804,1767.9250081380208

# %%
import fitz

pdf_dir = "C:/Users/samir/OneDrive/Desktop/Data Extraction/Train Files/1040_file_33.pdf"  # Replace with your PDF file path
doc = fitz.open(pdf_dir)
page = doc[0]

# Given coordinates

#target_x0, target_y0,target_x1,target_y1=2224.6124267578125,2729.699961344401, 2281.371053059896,2769.775136311849
# target_x0, target_y0 = 175.3499984741211, 504.62296803792316
# target_x1, target_y1 = 306.6750208536784, 542.1229680379232
blocks = page.get_text("dict")['blocks']
text_blocks = [block for block in blocks if block['type'] == 0]

target_text = None

for block in text_blocks:
    for line in block['lines']:
        for span in line['spans']:
            x0, y0, x1, y1 = [coord * TARGET_DPI / 72 for coord in span['bbox']]
            if target_x0 <= x0 <= target_x1 and target_y0 <= y0 <= target_y1 and \
               target_x0 <= x1 <= target_x1 and target_y0 <= y1 <= target_y1:
                target_text = span['text']

# Print the text at the given coordinates
if target_text is not None:
    print(f"Text at coordinates ({target_x0}, {target_y0}, {target_x1}, {target_y1}): {target_text}")
else:
    print(f"No text found at coordinates ({target_x0}, {target_y0}, {target_x1}, {target_y1})")
# Out:
# Text at coordinates (2190.979258219401, 1727.8500874837239, 2312.6050313313804, 1767.9250081380208): 9038.633

# %%
# First Name
#   175.3499984741211,493.64999135335285, 308.7000211079915,545.1749801635742
# last Name
#   1017.4500147501627,499.8230616251628, 1163.2874806722004,537.3230616251627
# 1a
#   2189.854176839193,1526.5500386555989, 2311.479949951172,1566.6249593098958
# Out:
#   File "<ipython-input-8-509ea4e8596e>", line 3
#     last Name
#          ^
# SyntaxError: invalid syntax
